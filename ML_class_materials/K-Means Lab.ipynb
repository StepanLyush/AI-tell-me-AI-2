# %%
# Lab assignment
# Extract and use the dataset (dataframe) that includes the following credit purposes: 
   ## radio/TV, furniture/equipment, and car
# Explore and prepare the dataset
# Create and evaluate a K-Means model with default parameters
# Create and evaluate a K-Means model with 'the best K' 
  ## (if the results of the Silhoutte and Elbow methods are not agreed or not clear,
  ## use each of the prominent K values to build and compare several models)
# Compare several internal clustering measures of the K-Means models.

# %%
# This credit bank dataset contains following columns:
# Sex (text: male, female)
# Job (numeric: 0 - unskilled and non-resident, 1 - unskilled and resident, 2 - skilled, 3 - highly skilled)
# Housing (text: own, rent, or free)
# Saving accounts (text: little, moderate, quite rich, or rich)
# Checking account (text: little, moderate, or rich)
# Credit amount (numeric: in DM)
# Duration (numeric: in months)
# Purpose (text: car, furniture/equipment, radio/tv, domestic appliances, repairs, education, business, vacation/other)
